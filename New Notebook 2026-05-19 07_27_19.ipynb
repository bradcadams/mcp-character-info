# %%
# %sql
SELECT
   c.character_id
  ,c.charcter_name
  ,c.alter_ego
  ,c.threat
  ,c.front_health
  ,c.back_health
  ,coalesce(c.front_health,0) + coalesce(c.back_health,0) total_health
  ,c.leadership_affiliation_id IS NOT NULL Has_Leadership
FROM
  mcp.game.characters c
  ;

SELECT
   ac.character_id
  ,ac.affiliation_name
FROM
  mcp.game.affiliated_charcters ac
  ;
/*
SELECT
  cu.character_id
  ,u.effective_date Update_Date
  ,date_format(u.effective_date,'yyyy') Update_Name
FROM
  mcp.game.character_updates cu
  INNER JOIN mcp.game.amg_updates u
    ON cu.update_key = u.update_key
    ;
*/
